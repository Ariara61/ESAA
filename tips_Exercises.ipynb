# %% [markdown]
# <a href="https://colab.research.google.com/github/Ariara61/ESAA/blob/main/tips_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tips

# %% [markdown]
# ### Introduction:
#
# This exercise was created based on the tutorial and documentation from [Seaborn](https://stanford.edu/~mwaskom/software/seaborn/index.html)
# The dataset being used is tips from Seaborn.
#
# ### Step 1. Import the necessary libraries:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
tips = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv")

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %%
tips.drop("Unnamed: 0", axis = 1, inplace = True)

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
# 방법 1
ax = plt.subplots()
ax = sns.distplot(tips["total_bill"], kde = False)
ax.set_xlabel("Total Bill")
ax.set_ylabel("Frequency")
ax.set_title("Total Bill Histogram")
# Out:
# <ipython-input-37-b58ad5ffc07f>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips["total_bill"], kde = False)
# Text(0.5, 1.0, 'Total Bill Histogram')

# %%
# 방법 2
ax = sns.histplot(tips, x = "total_bill")
ax.set_xlabel("Total Bill")
ax.set_ylabel("Frequency")
ax.set_title("Total Bill Histogram")
# Out:
# Text(0.5, 1.0, 'Total Bill Histogram')

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
# 방법 1
ax = plt.subplots()
ax = sns.regplot(x = "total_bill", y = "tip", data = tips, fit_reg = False)
ax.set_xlabel("Total Bill")
ax.set_ylabel("Tip")
ax.set_title("Scatter Plot fo Total Bill and Tip")
# Out:
# Text(0.5, 1.0, 'Scatter Plot fo Total Bill and Tip')

# %%
# 방법 2
ax = sns.scatterplot(x = "total_bill", y = "tip", data = tips)
ax.set_xlabel("Total Bill")
ax.set_ylabel("Tip")
ax.set_title("Scatter Plot fo Total Bill and Tip")
# Out:
# Text(0.5, 1.0, 'Scatter Plot fo Total Bill and Tip')

# %% [markdown]
# ### Step 7.  Create one image with the relationship of total_bill, tip and size.
# #### Hint: It is just one function.

# %%
sns.scatterplot(x = "total_bill", y = "tip", hue = "size", data = tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### Step 8. Present the relationship between days and total_bill value

# %%
ax = plt.subplots()
ax = sns.violinplot(x = "day", y = "total_bill", data = tips)

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %%
sns.scatterplot(x = "tip", y = "day", hue = "sex", data = tips)
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %%
sns.boxplot(x = "day", y = "total_bill", hue = "time", data = tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %%
facet = sns.FacetGrid(tips, col = "time")
facet.map(sns.histplot, "tip")
facet.add_legend()

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.

# %%
facet = sns.FacetGrid(tips, col = "sex", hue = "smoker")
facet.map(sns.scatterplot, "total_bill", "tip")
facet.add_legend()
